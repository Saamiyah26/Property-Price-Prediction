# %% [markdown]
# <a href="https://colab.research.google.com/github/Saamiyah26/Property-Price-Prediction/blob/main/data_merging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
flats=pd.read_csv('/content/drive/MyDrive/Property Price Prediction/flats_cleaned.csv')

# %%
houses=pd.read_csv('/content/drive/MyDrive/Property Price Prediction/house_cleaned.csv')

# %%
df=pd.concat([flats,houses],ignore_index=True)

# %%
df.sample(10)
# Out:
#                                        property_name property_type  \
# 2065                   2 BHK Flat in Sector-33 Sohna          flat
# 2508                        3 BHK Flat in Chakkarpur          flat
# 3473  4 Bedroom House for sale in Sohna Gurgaon Road         house
# 2517                 3 BHK Flat in Sector 65 Gurgaon          flat
# 34                   2 BHK Flat in Sector 90 Gurgaon          flat
# 2918                 3 BHK Flat in Sector 80 Gurgaon          flat
# 435                  3 BHK Flat in Sector 82 Gurgaon          flat
# 1197                 5 BHK Flat in Sector 62 Gurgaon          flat
# 3551          3 Bedroom House for sale in New Colony         house
# 1309                 3 BHK Flat in Sector 95 Gurgaon          flat
#
#                    society  price   price_per_sqft                       area  \
# 2065    godrej nature plus   1.20          14379.0                      835.0
# 2508           essel tower   2.20          12500.0                     1760.0
# 3473           independent   2.00   ₹ 7,479/sq.ft.  (248 sq.m.) Built-up Area
# 2517           m3m skycity   3.50          17039.0                     2054.0
# 34    shree vardhman flora   0.75           5769.0                     1300.0
# 2918       godrej frontier   1.60           7000.0                     2286.0
# 435    mapsko royale ville   0.99           5530.0                     1790.0
# 1197         pioneer araya  10.75          19500.0                     5513.0
# 3551           independent   6.50  ₹ 15,046/sq.ft.      (401 sq.m.) Plot Area
# 1309            rof ananda   0.38             58.0                    65517.0
#
#                                 areaWithType  bedroom  bathroom balcony  ...  \
# 2065                      Carpet area: 77.53        2         2       3  ...
# 2508        Carpet area: 1760 (163.51 sq.m.)        3         4      3+  ...
# 3473      Built Up area: 2674 (248.42 sq.m.)        4         3       0  ...
# 2517        Carpet area: 2054 (190.82 sq.m.)        3         3       3  ...
# 34          Carpet area: 1300 (120.77 sq.m.)        2         2       3  ...
# 2918  Super Built up area 2262(210.15 sq.m.)        3         3       3  ...
# 435    Super Built up area 1790(166.3 sq.m.)        3         4       2  ...
# 1197  Super Built up area 5514(512.27 sq.m.)        5         7       3  ...
# 3551             Plot area 480(401.34 sq.m.)        3         2      3+  ...
# 1309      Carpet area: 64412 (5984.07 sq.m.)        3         2       1  ...
#
#                                                 address floornum      facing  \
# 2065                  Sector-33 Sohna, Gurgaon, Haryana      1.0         NaN
# 2508                       Chakkarpur, Gurgaon, Haryana      3.0         NaN
# 3473  Sohna Gurgaon Road, Sohna Gurgaon Road, Gurgao...      NaN       North
# 2517                Sector 65 Gurgaon, Gurgaon, Haryana     15.0        East
# 34       Sector 90, Sector 90 Gurgaon, Gurgaon, Haryana      8.0  North-East
# 2918                Sector 80 Gurgaon, Gurgaon, Haryana      5.0         NaN
# 435      Sector 82, Sector 82 Gurgaon, Gurgaon, Haryana     14.0  South-West
# 1197          1302, Sector 62 Gurgaon, Gurgaon, Haryana     10.0  North-East
# 3551                       New Colony, Gurgaon, Haryana      NaN         NaN
# 1309                Sector 95 Gurgaon, Gurgaon, Haryana     12.0       North
#
#          agePossession                                    nearbyLocations  \
# 2065   Within 3 months  ['Signature Global Infinity Mall Sohna', 'Bads...
# 2508  5 to 10 Year Old  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3473         undefined                                                NaN
# 2517   Within 3 months  ['Sector 55 Metro Station', 'Eros City Square'...
# 34           undefined  ['IRIS Broadway Mall', 'Dwarka Expressway', 'S...
# 2918  5 to 10 Year Old  ['Pooja Clinic', 'Dr. Sahil Clinic', 'Prakash ...
# 435    0 to 1 Year Old  ['Sapphire 83 Mall', 'Golf Course Ext Rd', "St...
# 1197   1 to 5 Year Old  ['Paras Trinity Shopping Mall', 'Golf Course E...
# 3551      10+ Year Old  ['Geeta Nursing Home Gurgaon', 'Chiranjiv Hosp...
# 1309   1 to 5 Year Old  ['Metro', 'Dwarka Expressway', 'Rajeev Chowk',...
#
#                                             description  \
# 2065   2 bhk with private deck. Possession by july 2023
# 2508    It has a garden view and temple in the vicinity
# 3473  4bhk villa for resale in sohna gurgaon road so...
# 2517  This lovely 3 bhk apartment/flat in sector 65 ...
# 34    Best in class property available at sector 90 ...
# 2918  This 3 bhk flat in sector-80 gurgaon, gurgaon ...
# 435   Immediate visit possible. Call 99999-82787 for...
# 1197  3, 4 and 5 bhk residential apartments & pentho...
# 3551      Old construction house in new colony gurgaon.
# 1309  Ambitious, personable agent with 15 years of e...
#
#                                          furnishDetails  \
# 2065                                                NaN
# 2508  ['1 Water Purifier', '5 Fan', '1 Fridge', '1 E...
# 3473  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 2517  ['6 Fan', '1 Exhaust Fan', '3 Geyser', '1 Stov...
# 34    ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 2918                                                 []
# 435                                                 NaN
# 1197  ['4 Fan', '15 Light', '6 AC', '1 Modular Kitch...
# 3551                                                 []
# 1309                                                NaN
#
#                                                features  \
# 2065  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2508                                                NaN
# 3473                                                NaN
# 2517  ['Centrally Air Conditioned', 'Water purifier'...
# 34                                                  NaN
# 2918  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
# 435   ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1197  ['Security / Fire Alarm', 'Private Garden / Te...
# 3551                       ['Private Garden / Terrace']
# 1309  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
#
#                                                  rating no_of_floor
# 2065                                                NaN         NaN
# 2508  ['Environment3 out of 5', 'Lifestyle4 out of 5...         NaN
# 3473                                                NaN         1.0
# 2517  ['Environment4 out of 5', 'Lifestyle4 out of 5...         NaN
# 34    ['Green Area5 out of 5', 'Amenities5 out of 5'...         NaN
# 2918  ['Management3 out of 5', 'Green Area4 out of 5...         NaN
# 435   ['Green Area4.5 out of 5', 'Construction3 out ...         NaN
# 1197  ['Green Area5 out of 5', 'Construction4 out of...         NaN
# 3551  ['Environment4 out of 5', 'Lifestyle4 out of 5...         NaN
# 1309  ['Environment4 out of 5', 'Lifestyle4.5 out of...         NaN
#
# [10 rows x 21 columns]

# %%
df.to_csv('cleaned_data.csv',index=False)
