# %% [markdown]
# <a href="https://colab.research.google.com/github/Saamiyah26/Property-Price-Prediction/blob/main/data_merging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
flats=pd.read_csv('/content/drive/MyDrive/Property Price Prediction/flats_cleaned.csv')

# %%
houses=pd.read_csv('/content/drive/MyDrive/Property Price Prediction/house_cleaned1.csv')

# %%
df=pd.concat([flats,houses],ignore_index=True)

# %%
df.sample(10)
# Out:
#                                       property_name property_type  \
# 753                 3 BHK Flat in Sector 67 Gurgaon          flat
# 1266                4 BHK Flat in Sector 56 Gurgaon          flat
# 996                 3 BHK Flat in Sector 79 Gurgaon          flat
# 3670  5 Bedroom House for sale in Sector 33 Gurgaon         house
# 3721        5 Bedroom House for sale in Palam Vihar         house
# 843                 5 BHK Flat in Sector 83 Gurgaon          flat
# 901                 2 BHK Flat in Sector 85 Gurgaon          flat
# 2926                2 BHK Flat in Sector 22 Gurgaon          flat
# 484                 2 BHK Flat in Sector 74 Gurgaon          flat
# 3541        4 Bedroom House for sale in DLF Phase 3         house
#
#                        society  price   price_per_sqft                   area  \
# 753                 m3m merlin   3.40          14418.0                 2358.0
# 1266            the lions cghs   2.05           9534.0                 2150.0
# ...

# %%
df.to_csv('cleaned_data.csv',index=False)
